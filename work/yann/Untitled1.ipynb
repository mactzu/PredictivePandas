# %%
import numpy as np
import pandas as pd
import sklearn
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import linear_kernel
import joblib

# %%
model=joblib.load("../../data/kmean_model.sav")
scaler=joblib.load("../../data/mapper.bin")
beerdata=pd.read_csv("../eamonn/beerlist_w_Kmean.csv")

# %%
beerdata["numberof_reviews"].mode()
# Out:
# 0    2
# dtype: int64

# %%
#user input
beer_strength="Light"
overall=4
aroma=4
appearance=4
palate=4
taste=4
beer_style="lager"
words=["sweet","hay","toast","gentle","bubbly"]

# not user input
beer_style_all=["ale","barleywine","bitter","exotic","ipa","kölsch","lager","pilsener","porter","stout","trappist"]
beer_style_val=[0]*11
for i in range(len(beer_style_all)):
    if beer_style==beer_style_all[i]:
        beer_style_val[i]=1

beer_strength_all=["Light","Mid","Full","Heavy","Very Strong"]
beer_abv_all=[1,3.5,5,7.5,10.5]
beer_strength_val=[0]*5
for i in range(len(beer_strength_all)):
    if beer_strength==beer_strength_all[i]:
        beer_strength_val[i]=1
        beer_abv=beer_abv_all[i]

numberof_reviews=beerdata["numberof_reviews"].median()

# %%
userInput=np.array([[]])
    'beer_abv':beer_abv,
    "numberof_reviews":numberof_reviews,
    'review_overall':overall,
    'review_aroma':aroma,
    'review_appearance':appearance,
    'review_palate':palate,
    'review_taste':taste,
    'beer_style_ale':beer_style_val[0],
    'beer_style_barleywine':beer_style_val[1],
    'beer_style_bitter':beer_style_val[2],
    'beer_style_exotic':beer_style_val[3],
    'beer_style_ipa':beer_style_val[4],
    'beer_style_kölsch':beer_style_val[5],
    'beer_style_lager':beer_style_val[6],
    'beer_style_pilsener':beer_style_val[7],
    'beer_style_porter':beer_style_val[8],
    'beer_style_stout':beer_style_val[9],
    'beer_style_trappist':beer_style_val[10],
    'beer_strength_Full':beer_strength_val[2],
    'beer_strength_Heavy':beer_strength_val[3],
    'beer_strength_Light':beer_strength_val[0],
    'beer_strength_Mid':beer_strength_val[1],
    'beer_strength_Very Strong':beer_strength_val[4]}])
userInput=userInput.to_numpy()

# %%
userInput=np.array([[beer_abv,numberof_reviews,overall,aroma,
                    appearance,palate,taste,beer_style_val[0],
                    beer_style_val[1],beer_style_val[2],beer_style_val[3],
                    beer_style_val[4],beer_style_val[5],beer_style_val[6],
                    beer_style_val[7],beer_style_val[8],beer_style_val[9],
                    beer_style_val[10],beer_strength_val[2],beer_strength_val[3],
                    beer_strength_val[0],beer_strength_val[1],beer_strength_val[4]]])
userInput.shape
# Out:
# (1, 23)

# %%
cluster=model.predict(userInput)
print(cluster)
# Out:
# [0]

# %%
userInput
# Out:
#    beer_abv  numberof_reviews  review_overall  review_aroma  \
# 0         1               9.0               4             4
#
#    review_appearance  review_palate  review_taste  beer_style_ale  \
# 0                  4              4             4               0
#
#    beer_style_barleywine  beer_style_bitter  ...  beer_style_lager  \
# 0                      0                  0  ...                 1
#
#    beer_style_pilsener  beer_style_porter  beer_style_stout  \
# 0                    0                  0                 0
#
#    beer_style_trappist  beer_strength_Full  beer_strength_Heavy  \
# 0                    0                   0                    0
#
#    beer_strength_Light  beer_strength_Mid  beer_strength_Very Strong
# 0                    1                  0                          0
#
# [1 rows x 23 columns]

# %%
beerdata=beerdata[beerdata["Kmeans Cluster"]==cluster[0]]
#beerdata=beerdata[beerdata["beer_style"]=="lager"]
#beerdata

# %%
beerdata
# Out:
#        brewery_id                  brewery_name  beer_id  \
# 33              4      Allagash Brewing Company    58278
# 35              4      Allagash Brewing Company    58839
# 37              4      Allagash Brewing Company    62072
# 68              9                 Whitbread PLC    17237
# 71             14     Cambridge Brewing Company      454
# ...           ...                           ...      ...
# 13049       25680  Stanley Stawski Distributing    54020
# 13100       25923             Gueuzerie Tilquin    73100
# 13144       25960       Heretic Brewing Company    72964
# 13162       26520           Jack's Abby Brewing    71820
# 13227       27039                 The Alchemist    73943
#
#                               beer_name  \
# 33                      Allagash Avancé
# 35                Allagash Coolship Red
# 37                  Allagash Ghoulschip
# 68                       Mackeson Stout
# 71               Bannatyne's Scotch Ale
# ...                                 ...
# 13049             Stawski Premium Lager
# 13100  Gueuze Tilquin (Draught Version)
# 13144                       Evil Cousin
# 13162                    Hoponius Union
# 13227                          Luscious
#
#                                                  address  beer_abv  \
# 33            50 Industrial Way, Portland, ME 04103, USA      10.8
# 35            50 Industrial Way, Portland, ME 04103, USA       5.7
# 37            50 Industrial Way, Portland, ME 04103, USA       6.9
# 68     Whitbread Court Houghton Hall Business Park, P...       3.0
# 71     1 Kendall Square Bldg 100, Cambridge, MA 02139...       9.2
# ...                                                  ...       ...
# 13049       1811 W Fullerton Ave, Addison, IL 60101, USA       5.3
# 13100   Chaussée Maieur Habils 110, 1430 Rebecq, Belgium       4.8
# 13144          1052 Horizon Dr, Fairfield, CA 94533, USA       8.0
# 13162          100 Clinton St, Framingham, MA 01702, USA       6.7
# 13227        2222 4th St, White Bear Lake, MN 55110, USA      11.1
#
#        numberof_reviews  review_overall  review_aroma  review_appearance  ...  \
# 33                   29        3.948276      4.103448           4.051724  ...
# 35                   28        4.428571      4.339286           4.214286  ...
# 37                   27        4.240741      4.222222           3.944444  ...
# 68                   25        3.520000      3.500000           3.900000  ...
# 71                   26        4.173077      4.019231           4.096154  ...
# ...                 ...             ...           ...                ...  ...
# 13049                18        3.222222      3.083333           3.694444  ...
# 13100                37        4.067568      4.148649           3.824324  ...
# 13144                18        3.722222      3.666667           4.000000  ...
# 13162                22        4.340909      4.454545           4.136364  ...
# 13227                23        4.434783      4.217391           4.565217  ...
#
#        country_Tanzania  country_The Bahamas  country_Trinidad and Tobago  \
# 33                    0                    0                            0
# 35                    0                    0                            0
# 37                    0                    0                            0
# 68                    0                    0                            0
# 71                    0                    0                            0
# ...                 ...                  ...                          ...
# 13049                 0                    0                            0
# 13100                 0                    0                            0
# 13144                 0                    0                            0
# 13162                 0                    0                            0
# 13227                 0                    0                            0
#
#        country_Turks and Caicos Islands  country_UK  country_USA  \
# 33                                    0           0            1
# 35                                    0           0            1
# 37                                    0           0            1
# 68                                    0           1            0
# 71                                    0           0            1
# ...                                 ...         ...          ...
# 13049                                 0           0            1
# 13100                                 0           0            0
# 13144                                 0           0            1
# 13162                                 0           0            1
# 13227                                 0           0            1
#
#        country_USVI  country_Ukraine  country_United States  Kmeans Cluster
# 33                0                0                      0               0
# 35                0                0                      0               0
# 37                0                0                      0               0
# 68                0                0                      0               0
# 71                0                0                      0               0
# ...             ...              ...                    ...             ...
# 13049             0                0                      0               0
# 13100             0                0                      0               0
# 13144             0                0                      0               0
# 13162             0                0                      0               0
# 13227             0                0                      0               0
#
# [1894 rows x 282 columns]

# %%
beerdata.columns[187]
# Out:
# 'malty'

# %%
matrix=pd.DataFrame()
for i in range(12,187):
    matrix[beerdata.columns[i]]=beerdata[beerdata.columns[i]]/beerdata["numberof_reviews"]
matLen=len(matrix)
for i in range(12,187):    
    for j in words:
        if beerdata.columns[i]==j:
            matrix.loc[matLen,beerdata.columns[i]]=1
        else:
            matrix.loc[matLen,beerdata.columns[i]]=0

# %%
matrix
# Out:
#           malty    grainy     sweet  corn-like       hay     straw   cracker  \
# 24     0.000880  0.000000  0.004401        0.0  0.000000  0.005282  0.001761
# 111    0.000912  0.000000  0.016423        0.0  0.000000  0.000000  0.001825
# 143    0.000000  0.000000  0.023739        0.0  0.000000  0.000000  0.000000
# 187    0.002812  0.000000  0.011246        0.0  0.000000  0.000937  0.000937
# 231    0.000000  0.000000  0.012647        0.0  0.000000  0.000000  0.000000
# 234    0.009881  0.000988  0.013834        0.0  0.000988  0.000000  0.000000
# 239    0.000959  0.000959  0.006711        0.0  0.000959  0.004794  0.000000
# 240    0.003945  0.000986  0.025641        0.0  0.000000  0.000000  0.000000
# 242    0.004472  0.000000  0.010733        0.0  0.000000  0.000000  0.000000
# 252    0.008427  0.000000  0.014045        0.0  0.000000  0.000000  0.000000
# 298    0.003071  0.000000  0.013306        0.0  0.000000  0.000000  0.000000
# 309    0.004541  0.000908  0.003633        0.0  0.000000  0.000000  0.000000
# 346    0.007491  0.000000  0.013109        0.0  0.000000  0.000000  0.000000
# 412    0.004789  0.000000  0.012452        0.0  0.000000  0.000000  0.000000
# 448    0.001887  0.000000  0.002830        0.0  0.000000  0.000000  0.000000
# 669    0.000986  0.000986  0.015779        0.0  0.000000  0.000000  0.000986
# 677    0.005208  0.000000  0.008681        0.0  0.000000  0.000000  0.000000
# 681    0.005900  0.000000  0.009833        0.0  0.000000  0.000000  0.000000
# 702    0.003956  0.000989  0.012859        0.0  0.000989  0.000000  0.000989
# 755    0.000962  0.000962  0.012512        0.0  0.000000  0.000000  0.000000
# 760    0.011638  0.000000  0.010743        0.0  0.000895  0.000000  0.000000
# 863    0.002620  0.000000  0.002620        0.0  0.000000  0.000000  0.000000
# 864    0.000000  0.000000  0.003918        0.0  0.000000  0.006856  0.000000
# 1145   0.001727  0.000000  0.004318        0.0  0.000000  0.000000  0.000000
# 1152   0.006699  0.000000  0.011483        0.0  0.000000  0.000000  0.000000
# 1243   0.000000  0.005742  0.007656        0.0  0.001914  0.000957  0.000000
# 1252   0.005848  0.000000  0.010721        0.0  0.000000  0.000000  0.000000
# 1294   0.005282  0.000000  0.011444        0.0  0.000000  0.000000  0.000000
# 1297   0.004912  0.000000  0.030452        0.0  0.000982  0.000000  0.000000
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [51 rows x 175 columns]

# %%
cosine_similarity=linear_kernel(matrix,matrix)

# %%
similarity_scores = list(enumerate(cosine_similarity[len(cosine_similarity)-1]))
similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
similarity_scores = similarity_scores[1:6]
beers_index = [i[0] for i in similarity_scores]
for i in beers_index:
    print(beerdata.iloc[i,3])
# Out:
# 386
# 577
# 2264
# 8297
# 656

# %%
a=beerdata["beer_id"].values.to_array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-1abd07302e15> in <module>
# ----> 1 a=beerdata["beer_id"].values.to_array
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_array'

# %%
a
# Out:
# <PandasArray>
# [   59,   694,  7520,  2729,   108,  1193,  8297, 14309, 20564, 47785,   593,
#    148,   155,   198,   205,   411,   572,   577,   386,   361,  1173, 42533,
#  48434,  1914,   611,   656,   674,  1372,  2264,   722, 27804,  1009,  3833,
#   2137,  1655,  1658, 22227, 22790, 25755, 17538, 21822, 34146, 35036,  8919,
#  28577, 43687,   311,   199, 35720, 34688]
# Length: 50, dtype: int64

# %%
b=[1,2,3,4,5]
b
# Out:
# [1, 2, 3, 4, 5]

# %%
beerdata["cluster"].value_counts()
# Out:
# 0     7284
# 20    2340
# 10    1101
# 8      693
# 4      429
# 21     277
# 9      218
# 16     193
# 2      139
# 14     125
# 18      81
# 5       81
# 17      59
# 11      59
# 1       49
# 13      33
# 7       31
# 15      17
# 3       15
# 6       14
# 19       5
# 12       3
# Name: cluster, dtype: int64

# %%
beerdata[beerdata["cluster"]==12]
# Out:
#       Unnamed: 0  brewery_id               brewery_name  beer_id  \
# 670          670         112    North Coast Brewing Co.      412
# 856          856         140  Sierra Nevada Brewing Co.     1904
# 8840        8840       10099       Dogfish Head Brewery     2093
#
#                                 beer_name  \
# 670   Old Rasputin Russian Imperial Stout
# 856         Sierra Nevada Celebration Ale
# 8840                        90 Minute IPA
#
#                                               address  beer_abv  \
# 670          444 N Main St, Fort Bragg, CA 95437, USA       9.0
# 856    100 Sierra Nevada Way, Fletcher, NC 28732, USA       6.8
# 8840  6 Cannery Village Center, Milton, DE 19968, USA       9.0
#
#       numberof_reviews  review_overall  review_aroma  ...  country_Tanzania  \
# 670               3110        4.174116      4.198553  ...                 0
# 856               2999        4.168556      4.082194  ...                 0
# 8840              3289        4.145485      4.213439  ...                 0
#
#       country_The Bahamas  country_Trinidad and Tobago  \
# 670                     0                            0
# 856                     0                            0
# 8840                    0                            0
#
#       country_Turks and Caicos Islands  country_UK  country_USA  country_USVI  \
# 670                                  0           0            1             0
# 856                                  0           0            1             0
# 8840                                 0           0            1             0
#
#       country_Ukraine  country_United States  cluster
# 670                 0                      0       12
# 856                 0                      0       12
# 8840                0                      0       12
#
# [3 rows x 283 columns]

# %%
similarity_scores = list(enumerate(cosine_similarity[0]))
similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
similarity_scores = similarity_scores[1:6]
beers_index = [i[0] for i in similarity_scores]
print(beers['beer_id'].iloc[beers_index])
# Out:
# 10659    65239
# 10898    76099
# 7430     64411
# 4681     73841
# 12732    66752
# Name: beer_id, dtype: int64

# %%
beers_index
# Out:
# [10659, 10898, 7430, 4681, 12732]
